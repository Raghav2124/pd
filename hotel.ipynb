# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# File c:\Users\raghav.aggarwal\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
#      79     StringDtype,
#      80     BooleanDtype,
# ...

# %%
data=pd.read_csv("hotel_bookings.csv")

# %%
data.shape#this is used to find out number of rows and columns in the data set  and itis an attribute of pandas data frame
# Out:
# (119390, 32)

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
data.drop(["lead_time","is_canceled","arrival_date_month","days_in_waiting_list","reservation_status"],axis=1,inplace=True)
data
# Out:
#                hotel  arrival_date_year  arrival_date_week_number  \
# 0       Resort Hotel               2015                        27
# 1       Resort Hotel               2015                        27
# 2       Resort Hotel               2015                        27
# 3       Resort Hotel               2015                        27
# 4       Resort Hotel               2015                        27
# ...              ...                ...                       ...
# 119385    City Hotel               2017                        35
# 119386    City Hotel               2017                        35
# 119387    City Hotel               2017                        35
# 119388    City Hotel               2017                        35
# 119389    City Hotel               2017                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   arrival_date_year               119390 non-null  int64
#  2   arrival_date_week_number        119390 non-null  int64
#  3   arrival_date_day_of_month       119390 non-null  int64
#  4   stays_in_weekend_nights         119390 non-null  int64
#  5   stays_in_week_nights            119390 non-null  int64
#  6   adults                          119390 non-null  int64
#  7   children                        119386 non-null  float64
#  8   babies                          119390 non-null  int64
#  9   meal                            119390 non-null  object
#  10  country                         118902 non-null  object
#  11  market_segment                  119390 non-null  object
# ...

# %%
data.isnull()
# Out:
#         hotel  arrival_date_year  arrival_date_week_number  \
# 0       False              False                     False
# 1       False              False                     False
# 2       False              False                     False
# 3       False              False                     False
# 4       False              False                     False
# ...       ...                ...                       ...
# 119385  False              False                     False
# 119386  False              False                     False
# 119387  False              False                     False
# 119388  False              False                     False
# 119389  False              False                     False
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                           False                    False
# 1                           False                    False
# 2                           False                    False
# ...

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# arrival_date_year                      0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# customer_type                          0
# ...

# %%
data=data.sample(5000)

# %%
data.isnull().sum().sum()
# Out:
# 5383

# %%
data["company"].fillna("try")
# Out:
# 22167    try
# 88662    try
# 3922     try
# 1415     try
# 42514    try
#         ...
# 83018    try
# 63661    try
# 73435    try
# 26870    try
# 43455    try
# Name: company, Length: 5000, dtype: object

# %%
data.drop(["customer_type"],axis=1,inplace=True)
data
# Out:
#               hotel  arrival_date_year  arrival_date_week_number  \
# 22167  Resort Hotel               2016                        12
# 88662    City Hotel               2016                        20
# 3922   Resort Hotel               2016                         6
# 1415   Resort Hotel               2015                        35
# 42514    City Hotel               2015                        37
# ...             ...                ...                       ...
# 83018    City Hotel               2016                         3
# 63661    City Hotel               2017                         7
# 73435    City Hotel               2017                        34
# 26870  Resort Hotel               2016                        33
# 43455    City Hotel               2015                        38
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 22167                         19                        0
# 88662                          8                        2
# ...

# %%
data.shape
# Out:
# (5000, 26)

# %%
nf=data.dropna()

# %%
nf.reset_index(inplace=True)

# %%
nf.sort_values(by="arrival_date_year",inplace=True)
nf
# Out:
# C:\Users\raghav.aggarwal\AppData\Local\Temp\ipykernel_10464\3450400619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nf.sort_values(by="arrival_date_year",inplace=True)
#    index         hotel  arrival_date_year  arrival_date_week_number  \
# 0   2966  Resort Hotel               2015                        46
# 1  18252  Resort Hotel               2015                        45
# 2   2983  Resort Hotel               2015                        46
# 3  18255  Resort Hotel               2015                        46
# 4  43580    City Hotel               2015                        39
# 5   2945  Resort Hotel               2015                        45
# 6  93017    City Hotel               2016                        29
# ...

# %%
data["hotel"].value_counts()
# Out:
# hotel
# City Hotel      3339
# Resort Hotel    1661
# Name: count, dtype: int64

# %%
data.tail()
# Out:
#               hotel  arrival_date_year  arrival_date_week_number  \
# 83018    City Hotel               2016                         3
# 63661    City Hotel               2017                         7
# 73435    City Hotel               2017                        34
# 26870  Resort Hotel               2016                        33
# 43455    City Hotel               2015                        38
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 83018                         12                        0
# 63661                         17                        0
# 73435                         21                        2
# 26870                          7                        2
# 43455                         18                        0
#
#        stays_in_week_nights  adults  children  babies meal  ...  \
# 83018                     1       1       0.0       0   BB  ...
# 63661                     2       2       0.0       0   BB  ...
# ...

# %%
s=pd.concat([data,nf])
s
# Out:
#               hotel  arrival_date_year  arrival_date_week_number  \
# 22167  Resort Hotel               2016                        12
# 88662    City Hotel               2016                        20
# 3922   Resort Hotel               2016                         6
# 1415   Resort Hotel               2015                        35
# 42514    City Hotel               2015                        37
# ...             ...                ...                       ...
# 4        City Hotel               2015                        39
# 5      Resort Hotel               2015                        45
# 6        City Hotel               2016                        29
# 7      Resort Hotel               2017                        32
# 8      Resort Hotel               2017                         1
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 22167                         19                        0
# 88662                          8                        2
# ...

# %%
s1=pd.concat([data,nf],axis=1,join='inner')
s1
# Out:
# Empty DataFrame
# Columns: [hotel, arrival_date_year, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, adr, required_car_parking_spaces, total_of_special_requests, reservation_status_date, index, hotel, arrival_date_year, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, adr, required_car_parking_spaces, total_of_special_requests, reservation_status_date]
# Index: []
#
# [0 rows x 53 columns]

# %%
print(data.to_string())
# Out:
#                hotel  arrival_date_year  arrival_date_week_number  arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  adults  children  babies       meal country market_segment distribution_channel  is_repeated_guest  previous_cancellations  previous_bookings_not_canceled reserved_room_type assigned_room_type  booking_changes deposit_type  agent  company     adr  required_car_parking_spaces  total_of_special_requests reservation_status_date
# 22167   Resort Hotel               2016                        12                         19                        0                     1       1       0.0       0         BB     PRT  Offline TA/TO                TA/TO                  0                       0                               0                  D                  D                0   No Deposit  330.0      NaN   65.00                            0                          0              2016-03-20
# ...

# %%
print(data.loc[:,"hotel":"stays_in_weekend_nights"])
# Out:
#               hotel  arrival_date_year  arrival_date_week_number  \
# 22167  Resort Hotel               2016                        12
# 88662    City Hotel               2016                        20
# 3922   Resort Hotel               2016                         6
# 1415   Resort Hotel               2015                        35
# 42514    City Hotel               2015                        37
# ...             ...                ...                       ...
# 83018    City Hotel               2016                         3
# 63661    City Hotel               2017                         7
# 73435    City Hotel               2017                        34
# 26870  Resort Hotel               2016                        33
# 43455    City Hotel               2015                        38
#
#        arrival_date_day_of_month  stays_in_weekend_nights
# 22167                         19                        0
# 88662                          8                        2
# ...

# %%
gf1=data.groupby("arrival_date_year")

# %%
print(gf1["stays_in_week_nights"].sum())
# Out:
# arrival_date_year
# 2015    2199
# 2016    5795
# 2017    4574
# Name: stays_in_week_nights, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
arrival=[]
year=[]

# %%
d=gf1.groupby('')["stays_in_week_nights"].sum().to_dict()

for a,b in d.items():
    arrival.append(b)
    year.append(a)
    print(a,b)
# Out:
# 2015 2199
# 2016 5795
# 2017 4574

# %%
plt.plot(arrival,year)

# %%
data.columns
# Out:
# Index(['hotel', 'arrival_date_year', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests', 'reservation_status_date'],
#       dtype='object')

# %%
data["arrival_date_week_number"].mean()
# Out:
# 26.9804

# %%
plt.scatter(arrival,year)

# %%
data["arrival_date_week_number"].median()
# Out:
# 27.0

# %%
data["arrival_date_week_number"].min()
# Out:
# 1

# %%
gf1.first()
# Out:
#                           hotel  arrival_date_week_number  \
# arrival_date_year
# 2015               Resort Hotel                        35
# 2016               Resort Hotel                        12
# 2017                 City Hotel                        28
#
#                    arrival_date_day_of_month  stays_in_weekend_nights  \
# arrival_date_year
# 2015                                      28                        2
# 2016                                      19                        0
# 2017                                      12                        0
#
#                    stays_in_week_nights  adults  children  babies meal  \
# arrival_date_year
# 2015                                  4       2       0.0       0   BB
# 2016                                  1       1       0.0       0   BB
# 2017                                  3       2       0.0       0   BB
#
#                   country  ... reserved_room_type assigned_room_type  \
# ...

# %%
data.iloc[0:200,1:13]
# Out:
#        arrival_date_year  arrival_date_week_number  arrival_date_day_of_month  \
# 22167               2016                        12                         19
# 88662               2016                        20                          8
# 3922                2016                         6                          6
# 1415                2015                        35                         28
# 42514               2015                        37                          6
# ...                  ...                       ...                        ...
# 52931               2016                        25                         14
# 59210               2016                        43                         22
# 91994               2016                        27                         27
# 51082               2016                        20                         13
# 85417               2016                        11                         12
#
# ...

# %%
res = pd.merge(data, nf, on='arrival_date_year')

# %%
res
# Out:
#             hotel_x  arrival_date_year  arrival_date_week_number_x  \
# 0      Resort Hotel               2016                          12
# 1        City Hotel               2016                          20
# 2      Resort Hotel               2016                           6
# 3      Resort Hotel               2015                          35
# 4      Resort Hotel               2015                          35
# ...             ...                ...                         ...
# 11215    City Hotel               2015                          38
# 11216    City Hotel               2015                          38
# 11217    City Hotel               2015                          38
# 11218    City Hotel               2015                          38
# 11219    City Hotel               2015                          38
#
#        arrival_date_day_of_month_x  stays_in_weekend_nights_x  \
# 0                               19                          0
# ...

# %%
data["hotel"].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
gf1.size()
# Out:
# arrival_date_year
# 2015     888
# 2016    2332
# 2017    1780
# dtype: int64

# %%
# plt.scatter(data["arrival_date_week_number"],data["arrival_date_year"])
# plt.show()
